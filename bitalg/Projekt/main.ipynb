# %%
from bitalg.Projekt.delaunay import triangulate
from bitalg.Projekt.utils.generators.csv_files import load_points_from_csv, save_points_to_csv, save_triangulation_to_csv
from bitalg.Projekt.utils.generators.generate_points import generate_uniform_points
from bitalg.Projekt.utils.generators.mouse_point_generator import  get_points_interactive
from bitalg.Projekt.utils.generators.circle_points import generate_circle_points
from bitalg.visualizer.main import Visualizer
from bitalg.Projekt.utils.classes.Point import Point

# %%
points = generate_uniform_points(-10,10,6)

# %%
# %matplotlib tk
x_min = -10
x_max = 10
y_min= -10
y_max = 10

points = get_points_interactive(x_min,x_max,y_min,y_max)

# %%
filename = "losowe"
save_points_to_csv(points,filename)
# Out:
# Pomyślnie zapisano 5 punktów do losowe

# %%
filename = "losowe"
points = load_points_from_csv(filename)
# Out:
# Pomyślnie wczytano 5 punktów z losowe

# %%
# %matplotlib inline
vis = Visualizer()
x_min = -10
x_max = 10
y_min= -10
y_max = 10
vis.set_limits((3*x_min,3*x_max),(3*y_min,3*y_max))
vis.add_point(list(map(lambda x: x.get_cords(),points)))
vis.axis_equal()
vis.show()
vis.clear()
vis.axis_equal()
vis.set_limits((-30,30),(-30,30))

# %%
#wariant = "JaW"
wariant = "Graph"

# %%
triangles = triangulate(points,wariant,vis)
#triangle_filename
#save_triangulation_to_csv(triangles,triangle_filename)

# %%
vis.show()

# %%
vis.show_gif()
